# %% [markdown]
# <a href="https://colab.research.google.com/github/junggangwo/pdm07/blob/main/py-tensorflow/pdm07_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # transfer learning

# %% [markdown]
# transfer learning(TL)이란? - 트랜스퍼 러닝이란 딥러닝을 feature extractor로만 사용하고 그렇게 추출한 피처를 가지고 다른 모델을 학습하는 것입니다. 종류로는 ResNet, ConvNet, VGG 등이 있습니다.

# %% [markdown]
# 1. transfer learning을  사용하면 새 모델을 처음부터 다시 학습 시킬 필요없이 대규모 데이터 세트의 장점을 활용가능하다 .

# %% [markdown]
# 2.약간의 훈련이 필요하지만 새 데이터 세트를 추가하는 부분 때문입니다.

# %% [markdown]
# # transfer learning 배경

# %% [markdown]
#  Transfer Learning의 배경은 우리 주변 세계의 일반적인 모델 역할을 할 수 있는 충분히 큰 이미지 데이터 세트에서 훈련된 사전 훈련된 네트워크를 사용하는 것입니다. 그런 다음 분류하려는 이미지에서 이 훈련된 네트워크를 사용하고, 모델을 조정하고, 새로운 아키텍처를 실행하여 찾고 있는 분류 결과를 볼 수 있습니다. 사전 훈련된 네트워크를 사용하는 방법에는 두 가지가 있습니다.
#
# 1.특징 추출
# 2.미세 조정

# %% [markdown]
# # 실험목적

# %% [markdown]
# 이 실험의 목적은 첫 번째 옵션인 특징 추출에 초점을 맞추는 것이며 ImageNet 아키텍처인 ResNet50을 사전 훈련된 모델로 사용합니다. VGG16, VGG19, MobileNet 등과 같이 선택할 수 있는 전이 학습 아키텍처가 많이 있습니다. 모두 특정 상황에 대한 장단점이 있습니다. 예를 들어 MobileNet은 빠르고 유연하며 모바일 장치에서 가장 잘 작동합니다. 이 모델은 140만 개의 레이블이 지정된 이미지와 1000개의 다른 클래스가 포함된 ImageNet 데이터 세트에서 훈련됩니다. 분류하려는 작은 데이터 세트로 특정 공간 기능을 캡처하기에 데이터가 충분하지 않을 수 있다는 사실을 감안할 때 이것은 훌륭합니다. ImageNet에서 훈련된 ResNet50 아키텍처의 예는 이미지 1에 나와 있습니다.

# %% [markdown]
# # cifar -10

# %% [markdown]
# CIFAR-10 문서에서 "CIFAR-10 데이터 세트는 10개 클래스의 60000개의 32x32 컬러 이미지로 구성되며 클래스당 6000개의 이미지가 있습니다. 50000개의 훈련 이미지와 10000개의 테스트 이미지가 있습니다.” 하지만 기존의 문서와 다르게 **10% data **
#
# 이용하여 데이터 개수를 줄여 이 시나리오에서 모델을 훈련하고 테스트할 때 활용합니다. CIFAR-10 데이터 세트의 매우 유리한 기능 중 하나는 이미지를 별도로 다운로드하여 디렉토리에 로드할 필요가 없다는 것입니다. Keras Datasets 패키지에서 가져올 수 있습니다. ResNet50은 이미지가 최소 200x200픽셀이어야 하는 반면 CIFAR-10 데이터세트에는 32x32픽셀의 이미지가 있어야 하기 때문에 사전 처리가 필요합니다. 이는 이미지를 사전에 모양을 변경하거나 이미지를 컨볼루션 레이어에 입력하기 전에 이미지로 확대하여 수행할 수 있습니다. 이미지 2는 CIFAR-10 데이터 세트에 포함된 사진의 몇 가지 예를 보여줍니다.

# %% [markdown]
# Transfer Learning은 충분히 큰 데이터 세트가 없는 실험을 실행할 때 사용할 수 있는 훌륭한 기술입니다. 활용할 수 있는 모델이 상당히 많이 있으며 대부분은 140만 개 이상의 이미지가 있는 ImageNet 데이터 세트에서 훈련되었습니다. 이 사전 훈련된 네트워크는 위에서 볼 수 있듯이 많은 공간 계층을 캡처하고 훈련되지 않은 데이터 세트를 입력할 때 훌륭한 작업을 수행합니다. 모델이 끝날 때까지 완전히 연결된 네트워크를 조정해야 하지만 높은 분류 정확도로 끝납니다.

# %% [markdown]
#  최고 성능 모델을 저장하여 혼동행렬하였을 때
# 80% 90 % 로 정확도가 상승하였습니다
#
# ---

# %% [markdown]
# # 부족했던 점

# %% [markdown]
# . confusion_matrix를 만들 때 testX, testy로 예측치에 잘못 넣어 confusion_matrix가 한쪽으로 쏠리는 matrix가 나왔습니다. 그런데 x_test, y_test를 넣어본 결과 현재 나온 matrix가 최종적으로 나왔습니다.
#
# > 들여쓴 블록

# %% [markdown]
# # Transfer Learning and Visualization (CNN's)
# - cifar-10
# - resnet50
# - mobilenetV2
#
# > https://medium.com/@andrew.dabydeen/transfer-learning-using-resnet50-and-cifar-10-6242ed4b4245

# %% [markdown]
# ### Transfer learning (imagenet)
# - ImageNet dataset
#     - 1.4 million labeled images
#     - 1,000 different classes
#
# tensorflow.keras.applications
# - Xception
# - Inception V3
# - ResNet50
# - VGG16
# - VGG19
# - MobileNet
#
# > [ref1-architecture-comparison-of-alexnet-vggnet-resnet-inception-densenet](https://towardsdatascience.com/architecture-comparison-of-alexnet-vggnet-resnet-inception-densenet-beb8b116866d)
#
# > [ref2-imagenet-vggnet-resnet-inception-xception-keras](https://www.pyimagesearch.com/2017/03/20/imagenet-vggnet-resnet-inception-xception-keras/)

# %% [markdown]
# This Colab notebook demonstrates transfer learning with a pretrained ConvNet: MobileNetV2
#
# 0.   Data pipeline
# 1.   Baseline model: train a simple CNN from scratch
# 2.   Transfer learning: pretraiend ConvNet as a feature extractor
# 3.   Transfer learning: fine-tune a pretrained ConvNet
# 4.   Test accuracy & visualize predictions

# %% [markdown]
# Before beginning, let's load the appropriate libraries needed for this notebook

# %% [markdown]
# # ConvNet: MobileNetV2

# %%
# from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.applications.mobilenet_v2 import  MobileNetV2, preprocess_input
import tensorflow.keras as keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from keras.utils import np_utils
from keras.models import load_model
from keras.datasets import cifar10
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# import cv2
print(tf.__version__)
# Out:
# 2.7.0

# %%
tf.keras.backend.clear_session()  # For memory

# GPU check
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print("#### ", len(gpus), "Physical GPUs,",
                 len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
else:
    print('#### No CUDA supported GPU in this computer.')
# Out:
# ####  1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Load data
# - Use total data

# %%
from keras.datasets import cifar10
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
trainX=trainX[:5000]
trainy=trainy[:5000]

# %% [markdown]
# ## Data augmentation

# %%
# data augumatation
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
        featurewise_center=False, 
        featurewise_std_normalization=False, 
        rotation_range=25,
        width_shift_range=0.2, 
        height_shift_range=0.2, 
        vertical_flip=False,
        horizontal_flip=True)
datagen.fit(trainX)

# %% [markdown]
# ---

# %% [markdown]
# ### Visualize Dataset
#
# Use the `display_images` to view some of the images and their class labels.

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import os
# Matplotlib config
# plt.rc('image', cmap='gray')
plt.rc('grid', linewidth=0)
plt.rc('xtick', top=False, bottom=False, labelsize='large')
plt.rc('ytick', left=False, right=False, labelsize='large')
plt.rc('axes', facecolor='F8F8F8', titlesize="large", edgecolor='white')
plt.rc('text', color='000000')
plt.rc('figure', facecolor='F0F0F0')# Matplotlib fonts
MATPLOTLIB_FONT_DIR = os.path.join(os.path.dirname(plt.__file__), "mpl-data/fonts/ttf")

# utility to display a row of digits with their predictions
def display_images(digits, predictions, labels, title):

  n = 10

  indexes = np.random.choice(len(predictions), size=n)
  n_digits = digits[indexes]
  n_predictions = predictions[indexes]
  n_predictions = n_predictions.reshape((n,))
  n_labels = labels[indexes]
 
  fig = plt.figure(figsize=(20, 4))
  plt.title(title)
  plt.yticks([])
  plt.xticks([])

  for i in range(10):
    ax = fig.add_subplot(1, 10, i+1)
    class_index = n_predictions[i]
    true_index = n_labels[i]
    # Set x-label color: green if prediction correct and red if prediction incorrect
    plt.xlabel(classes[class_index])
    xlabel_color = "green" if n_predictions[i] == n_labels[i] else "red"
    ax.xaxis.label.set_color(xlabel_color) 
    plt.xticks([])
    plt.yticks([])
    plt.imshow(n_digits[i])

# %%
display_images(trainX, trainy, trainy, "Training Data" )

# %%
display_images(testX, testy, testy, "Validation Data" )

# %% [markdown]
# ## *Preprocess the dataset*

# %%
def preprocess_image_input(input_images):
  input_images = input_images.astype('float32')
  output_ims = preprocess_input(input_images)
  return output_ims

# %%
x_train = preprocess_image_input(trainX)
x_test = preprocess_image_input(testX)

# %%
x_train.shape,len(x_train),x_train[4].shape
# Out:
# ((5000, 32, 32, 3), 5000, (32, 32, 3))

# %%
y_train=trainy
y_test=testy
y_train.shape,y_test.shape
# Out:
# ((5000, 1), (10000, 1))

# %% [markdown]
# ## Transfer learning
#
# Now let's see how transfer learning can help achieve better results.
#
# - Feature extractor
#
# > Use MobileNetV2 as a feature extractor and add a classifier on top of it.

# %% [markdown]
# ## Define the Network
# We will be performing transfer learning on **MobileNetV2** available in Keras.
# - We'll load pre-trained **imagenet weights** to the model.
# - We'll choose to retain all layers of **MobileNetV2** along with the final classification layers.

# %%
'''
Feature Extraction is performed by MobileNetV2 pretrained on imagenet weights. 
Input size is 224 x 224.
'''
def feature_extractor(inputs):

  TL_base = MobileNetV2(input_shape=(224, 224, 3),
                                               include_top=False,
                                               weights='imagenet')
  #   Unfreeze top layers for fine tuning
  TL_base.trainable = False
  return TL_base(inputs)


'''
Defines final dense layers and subsequent softmax layer for classification.
'''
def classifier(inputs):
    x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1024, activation="relu")(x)
    x = tf.keras.layers.Dense(512, activation="relu")(x)
    x = tf.keras.layers.Dense(10, activation="softmax", name="classification")(x)
    return x

'''
Since input image size is (32 x 32), first upsample the image by factor of (7x7) to transform it to (224 x 224)
Connect the feature extraction and "classifier" layers to build the model.
'''
def final_model(inputs):

    resize = tf.keras.layers.UpSampling2D(size=(7,7))(inputs)

    resnet_feature_extractor = feature_extractor(resize)
    classification_output = classifier(resnet_feature_extractor)

    return classification_output

'''
Define the model and compile it. 
Use Stochastic Gradient Descent as the optimizer.
Use Sparse Categorical CrossEntropy as the loss function.
'''
def define_compile_model():
  inputs = tf.keras.layers.Input(shape=(32,32,3))
  
  classification_output = final_model(inputs) 
  model = tf.keras.Model(inputs=inputs, outputs = classification_output)
 
  model.compile(optimizer='SGD', 
                loss='sparse_categorical_crossentropy',  # y_train is NOT one-hot encoded!
                metrics = ['accuracy'])
  
  return model


model = define_compile_model()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  up_sampling2d (UpSampling2D  (None, 224, 224, 3)      0
#  )
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 10)                5130
#
# =================================================================
# Total params: 4,099,658
# Trainable params: 1,841,674
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
# Plot model
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model_F.png')

# %%
from tensorflow.keras import layers, models, callbacks

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./model/cifar10pct100_mobileNetV2F_SGD_best_weights.{epoch:03d}-{val_accuracy:.3f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)

# %% [markdown]
# ## Train the model

# %%
# %%time
EPOCHS = 100
BATCH_SIZE = 50  # 32, 50, 64, 100
history = model.fit(x_train, y_train, 
                    epochs=EPOCHS, 
                    validation_data = (x_test, y_test), 
                    batch_size=BATCH_SIZE,
                    callbacks=[mc_callback,es_callback])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 58s 551ms/step - loss: 1.7260 - accuracy: 0.4280 - val_loss: 1.3967 - val_accuracy: 0.5302
# Epoch 2/100
# 100/100 [==============================] - 35s 354ms/step - loss: 1.2433 - accuracy: 0.5822 - val_loss: 1.1877 - val_accuracy: 0.5889
# Epoch 3/100
# 100/100 [==============================] - 35s 353ms/step - loss: 1.0895 - accuracy: 0.6220 - val_loss: 1.1040 - val_accuracy: 0.6138
# Epoch 4/100
# 100/100 [==============================] - 53s 536ms/step - loss: 0.9943 - accuracy: 0.6584 - val_loss: 1.0710 - val_accuracy: 0.6240
# Epoch 5/100
# 100/100 [==============================] - 35s 354ms/step - loss: 0.9357 - accuracy: 0.6736 - val_loss: 1.0191 - val_accuracy: 0.6401
# Epoch 6/100
# 100/100 [==============================] - 53s 536ms/step - loss: 0.8849 - accuracy: 0.6974 - val_loss: 1.0068 - val_accuracy: 0.6466
# Epoch 7/100
# 100/100 [==============================] - 35s 353ms/step - loss: 0.8459 - accuracy: 0.7096 - val_loss: 0.9880 - val_accuracy: 0.6484
# Epoch 8/100
# 100/100 [==============================] - 35s 351ms/step - loss: 0.8056 - accuracy: 0.7248 - val_loss: 0.9883 - val_accuracy: 0.6565
# Epoch 9/100
# 100/100 [==============================] - 35s 352ms/step - loss: 0.7667 - accuracy: 0.7388 - val_loss: 0.9882 - val_accuracy: 0.6497
# Epoch 10/100
# 100/100 [==============================] - 35s 352ms/step - loss: 0.7399 - accuracy: 0.7442 - val_loss: 0.9970 - val_accuracy: 0.6473
# Epoch 11/100
# 100/100 [==============================] - 35s 352ms/step - loss: 0.7145 - accuracy: 0.7546 - val_loss: 0.9597 - val_accuracy: 0.6599
# Epoch 12/100
# 100/100 [==============================] - 35s 352ms/step - loss: 0.6859 - accuracy: 0.7650 - val_loss: 0.9588 - val_accuracy: 0.6602
# Epoch 13/100
# 100/100 [==============================] - 53s 535ms/step - loss: 0.6666 - accuracy: 0.7674 - val_loss: 1.0068 - val_accuracy: 0.6537
# Epoch 14/100
# 100/100 [==============================] - 35s 353ms/step - loss: 0.6440 - accuracy: 0.7778 - val_loss: 0.9170 - val_accuracy: 0.6794
# Epoch 15/100
# 100/100 [==============================] - 53s 535ms/step - loss: 0.6232 - accuracy: 0.7856 - val_loss: 0.9441 - val_accuracy: 0.6679
# Epoch 16/100
# 100/100 [==============================] - 35s 354ms/step - loss: 0.5928 - accuracy: 0.8010 - val_loss: 0.9741 - val_accuracy: 0.6578
# Epoch 17/100
# 100/100 [==============================] - 35s 353ms/step - loss: 0.5879 - accuracy: 0.8026 - val_loss: 0.9213 - val_accuracy: 0.6776
# Epoch 18/100
# 100/100 [==============================] - 53s 536ms/step - loss: 0.5558 - accuracy: 0.8076 - val_loss: 0.9180 - val_accuracy: 0.6729
# Epoch 19/100
# 100/100 [==============================] - 35s 353ms/step - loss: 0.5456 - accuracy: 0.8164 - val_loss: 1.0571 - val_accuracy: 0.6424
# Epoch 00019: early stopping
# CPU times: user 11min 15s, sys: 5.36 s, total: 11min 20s
# Wall time: 12min 59s

# %% [markdown]
# ## Evaluate the Model
#
# Calculate the loss and accuracy metrics using the model's `.evaluate` function.

# %%
model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 24s 121ms/step - loss: 1.0571 - accuracy: 0.6424
# [1.0571186542510986, 0.6424000263214111]

# %% [markdown]
# ## 훈련 데이터와 검증 데이터에 대한 loss, accuracy 시각화

# %%
# 훈련 데이터와 검증 데이터에 대한 loss 시각화.
epochs = range(1, len(history.history['loss']) + 1)

loss_list = history.history['loss'] #[100 * i for i in history.history['loss']]
vloss_list = history.history['val_loss'] #[100 * i for i in history.history['val_loss']]

plt.plot(epochs,loss_list)  
plt.plot(epochs,vloss_list)

plt.plot(np.argmin(np.array(vloss_list))+1,vloss_list[np.argmin(np.array(vloss_list))], 'r*')
plt.title('cifar10_100%: TL(mobilenetV2) Sequential model - val_loss, min:' + str(np.round(vloss_list[np.argmin(np.array(vloss_list))],2)))
plt.ylabel('val-Loss (%)')
plt.xlabel('Epoch')
plt.legend(['loss','val_loss','best'], loc='best')
plt.show()

# %%
# 훈련 데이터와 검증 데이터에 대한 accuracy 시각화.
epochs = range(1, len(history.history['accuracy']) + 1)

acc_list = [100 * i for i in history.history['accuracy']]
vacc_list = [100 * i for i in history.history['val_accuracy']]

plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)

plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*')
plt.title('cifar10_100%: TL(mobilenetV2) Sequential model - val_accuracy, max:' + str(np.round(vacc_list[np.argmax(np.array(vacc_list))],2)))
plt.ylabel('val-Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy','best'], loc='best')
plt.show()

# %% [markdown]
# ### Visualization loss & accuracy

# %% [markdown]
# The training/validation loss and accuracy visualizations are shown below

# %%
# More graphs of loss and accuracy
history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],3)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],3)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Visualize predictions
# We can take a look at the predictions on the validation set.

# %%
probabilities = model.predict(x_test, batch_size=BATCH_SIZE)
probabilities = np.argmax(probabilities, axis = 1)

display_images(testX, probabilities, testy, "Predictions of the validation data")

# %% [markdown]
# ---

# %% [markdown]
# # **Fine tuning**

# %%
tf.keras.backend.clear_session()  # For memory

# %%
'''
Feature Extraction is performed by MobileNetV2 pretrained on imagenet weights. 
Input size is 224 x 224.
'''
def feature_extractor_fine_tuning(inputs):

  TL_base = MobileNetV2(input_shape=(224, 224, 3),
                            include_top=False,
                            weights='imagenet')
#   Unfreeze top layers for fine tuning
  TL_base.trainable = True
  # Fine-tune from this layer onwards
  fine_tune_at = 107

  # Freeze all the layers before the `fine_tune_at` layer
  for layer in TL_base.layers[:fine_tune_at]:
    layer.trainable =  False

  return TL_base(inputs)

def final_model_ft(inputs):

    resize = tf.keras.layers.UpSampling2D(size=(7,7))(inputs)

    fine_feature_extractor = feature_extractor_fine_tuning(resize)
    classification_output = classifier(fine_feature_extractor)

    return classification_output

def define_compile_model_ft():
  inputs = tf.keras.layers.Input(shape=(32,32,3))
  
  classification_output = final_model_ft(inputs) 
  model = tf.keras.Model(inputs=inputs, outputs = classification_output)
 
  model.compile(optimizer='SGD', 
                loss='sparse_categorical_crossentropy',  # y_train is NOT one-hot encoded!
                metrics = ['accuracy'])
  
  return model

model = define_compile_model_ft()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  up_sampling2d (UpSampling2D  (None, 224, 224, 3)      0
#  )
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 10)                5130
#
# =================================================================
# Total params: 4,099,658
# Trainable params: 3,641,290
# Non-trainable params: 458,368
# _________________________________________________________________

# %%
from tensorflow.keras import layers, models, callbacks

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./model/cifar10pct100_mobileNetV2F_SGD_FT_best_weights.{epoch:03d}-{val_accuracy:.3f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)

# %% [markdown]
# ## Train the fine-tuned model

# %%
INITIAL_EPOCHS = len(loss)
FINE_TUNE_EPOCHS = 100
TOTAL_EPOCHS = INITIAL_EPOCHS + FINE_TUNE_EPOCHS #

# %%
# %%time
BATCH_SIZE = 50  # 32, 50, 64, 100
history_fine = model.fit(x_train, y_train, 
                    epochs=TOTAL_EPOCHS, 
                    initial_epoch=INITIAL_EPOCHS,
                    validation_data = (x_test, y_test), 
                    batch_size=BATCH_SIZE,
                    callbacks=[mc_callback,es_callback])
# Out:
# Epoch 20/119
# 100/100 [==============================] - ETA: 0s - loss: 1.5060 - accuracy: 0.5082
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 100/100 [==============================] - 46s 418ms/step - loss: 1.5060 - accuracy: 0.5082 - val_loss: 1.6463 - val_accuracy: 0.4210
# Epoch 21/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.7021 - accuracy: 0.7680 - val_loss: 1.4790 - val_accuracy: 0.4834
# Epoch 22/119
# 100/100 [==============================] - 41s 409ms/step - loss: 0.4039 - accuracy: 0.8720 - val_loss: 1.3611 - val_accuracy: 0.5338
# Epoch 23/119
# 100/100 [==============================] - 40s 404ms/step - loss: 0.2205 - accuracy: 0.9398 - val_loss: 1.3351 - val_accuracy: 0.5465
# Epoch 24/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.1243 - accuracy: 0.9746 - val_loss: 1.4108 - val_accuracy: 0.5549
# Epoch 25/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0698 - accuracy: 0.9898 - val_loss: 1.3241 - val_accuracy: 0.5870
# Epoch 26/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0441 - accuracy: 0.9962 - val_loss: 1.2673 - val_accuracy: 0.6082
# Epoch 27/119
# 100/100 [==============================] - 40s 404ms/step - loss: 0.0291 - accuracy: 0.9982 - val_loss: 1.3080 - val_accuracy: 0.6128
# Epoch 28/119
# 100/100 [==============================] - 40s 404ms/step - loss: 0.0199 - accuracy: 0.9992 - val_loss: 1.3000 - val_accuracy: 0.6341
# Epoch 29/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0140 - accuracy: 0.9996 - val_loss: 1.2848 - val_accuracy: 0.6451
# Epoch 30/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0114 - accuracy: 0.9996 - val_loss: 1.2170 - val_accuracy: 0.6676
# Epoch 31/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0108 - accuracy: 0.9994 - val_loss: 1.2212 - val_accuracy: 0.6803
# Epoch 32/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0084 - accuracy: 0.9996 - val_loss: 1.1466 - val_accuracy: 0.7000
# Epoch 33/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.1403 - val_accuracy: 0.7067
# Epoch 34/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0070 - accuracy: 0.9998 - val_loss: 1.0868 - val_accuracy: 0.7213
# Epoch 35/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.0433 - val_accuracy: 0.7360
# Epoch 36/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 1.0655 - val_accuracy: 0.7382
# Epoch 37/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 0.9773 - val_accuracy: 0.7566
# Epoch 38/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.9728 - val_accuracy: 0.7587
# Epoch 39/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9662 - val_accuracy: 0.7640
# Epoch 40/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0036 - accuracy: 0.9998 - val_loss: 0.9447 - val_accuracy: 0.7693
# Epoch 41/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.9258 - val_accuracy: 0.7731
# Epoch 42/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9362 - val_accuracy: 0.7736
# Epoch 43/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9121 - val_accuracy: 0.7801
# Epoch 44/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9149 - val_accuracy: 0.7806
# Epoch 45/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9000 - val_accuracy: 0.7834
# Epoch 46/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8889 - val_accuracy: 0.7849
# Epoch 47/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.8928 - val_accuracy: 0.7877
# Epoch 48/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.8844 - val_accuracy: 0.7907
# Epoch 49/119
# 100/100 [==============================] - 58s 587ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.7911
# Epoch 50/119
# 100/100 [==============================] - 40s 402ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8949 - val_accuracy: 0.7904
# Epoch 51/119
# 100/100 [==============================] - 58s 583ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8906 - val_accuracy: 0.7907
# Epoch 52/119
# 100/100 [==============================] - 58s 584ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.7905
# Epoch 53/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8875 - val_accuracy: 0.7943
# Epoch 54/119
# 100/100 [==============================] - 40s 401ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.9245 - val_accuracy: 0.7901
# Epoch 55/119
# 100/100 [==============================] - 58s 583ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.7942
# Epoch 56/119
# 100/100 [==============================] - 40s 402ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8997 - val_accuracy: 0.7917
# Epoch 57/119
# 100/100 [==============================] - 40s 405ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8922 - val_accuracy: 0.7955
# Epoch 58/119
# 100/100 [==============================] - 58s 584ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9007 - val_accuracy: 0.7954
# Epoch 59/119
# 100/100 [==============================] - 58s 583ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.9023 - val_accuracy: 0.7951
# Epoch 60/119
# 100/100 [==============================] - 58s 588ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8977 - val_accuracy: 0.7970
# Epoch 61/119
# 100/100 [==============================] - 40s 406ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.9025 - val_accuracy: 0.7980
# Epoch 62/119
# 100/100 [==============================] - 58s 584ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8974 - val_accuracy: 0.7972
# Epoch 63/119
# 100/100 [==============================] - 58s 583ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9077 - val_accuracy: 0.7970
# Epoch 64/119
# 100/100 [==============================] - 40s 402ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9085 - val_accuracy: 0.7977
# Epoch 65/119
# 100/100 [==============================] - 58s 583ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9104 - val_accuracy: 0.7965
# Epoch 66/119
# 100/100 [==============================] - 58s 584ms/step - loss: 8.7287e-04 - accuracy: 1.0000 - val_loss: 0.9103 - val_accuracy: 0.7975
# Epoch 00066: early stopping
# CPU times: user 31min 41s, sys: 15.7 s, total: 31min 57s
# Wall time: 39min 6s

# %% [markdown]
# ## Evaluate the Model
#
# Calculate the loss and accuracy metrics using the model's `.evaluate` function.

# %%
model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 24s 121ms/step - loss: 0.9103 - accuracy: 0.7975
# [0.9103428721427917, 0.7975000143051147]

# %% [markdown]
# ### Plot Loss and Accuracy Curves
#
# Plot the loss (in blue) and validation loss (in green).

# %%
# Display training curve

acc = history.history['accuracy'] + history_fine.history['accuracy']
val_acc = history.history['val_accuracy'] + history_fine.history['val_accuracy']

plt.figure(figsize=(8, 4))

plt.plot(acc, label='Train accuracy')
plt.plot(val_acc, label='Val accuracy')
# plt.ylim([0.8, 1])
plt.plot([INITIAL_EPOCHS-1, INITIAL_EPOCHS-1], plt.ylim(ymin=acc[0]), label='Start Fine Tuning')
plt.title("Fine-tune a Pretrained ConvNet:MobileNetV2-F")
plt.legend(loc='upper left')

plt.show()

# %%
# More graphs of loss and accuracy in Fine Tuning
history_dict = history_fine.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(INITIAL_EPOCHS, INITIAL_EPOCHS+len(loss))

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(INITIAL_EPOCHS + np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],3)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# epochs = range(1, len(loss_values) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy')#, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(INITIAL_EPOCHS + np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Fine Tuning: Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],3)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Best model
# - cifar10pct100_mobileNetV2F_SGD_FT_best_weights.037-0.889.hdf5

# %%
from keras.models import load_model

model_best = load_model('cifar10pct100_mobileNetV2F_SGD_FT_best_weights.037-0.889.hdf5')
model.evaluate(x_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 24s 237ms/step - loss: 0.9103 - accuracy: 0.7975
# [0.9103430509567261, 0.7975000143051147]

# %% [markdown]
# ### Visualize predictions
# We can take a look at the predictions on the validation set.

# %%
probabilities = model.predict(x_test, batch_size=BATCH_SIZE) #최종 모델로 테스트 데이터에서 예측
probabilities = np.argmax(probabilities, axis = 1)

display_images(testX, probabilities, testy, "Predictions of the validation data")

# %% [markdown]
# ---
#
# ---

# %%
tf.keras.backend.clear_session()  # For memory

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
predictions = model_best.predict(x_test)

# %%
predictions.shape
# Out:
# (10000, 10)

# %%
predictions0 = np.argmax(predictions, axis=1) #one-hot-encoding 위해
predictions0.shape
# Out:
# (10000,)

# %%
cm = confusion_matrix(y_test, predictions0)

# %%
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()
#반대각선은 정확히 예측한 개수

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %%
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(5,5))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
